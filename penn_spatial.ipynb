# %%
import geopandas as gpd
import pandas as pd
import sqlalchemy as sqa
from geoalchemy2 import Geography

df = gpd.read_file('__data__/penn/ef7af340-1817-41f6-ad5b-032f11d6d7872020328-1-54q7hz.msruy.shp')

df.rename_geometry('geog', inplace=True)

df = df.to_crs(epsg=4326)



studyarea = [
    "University of Pennsylvania"
]

df = df.query("NAME in @studyarea")



df
# Out:
#      OBJECTID                        NAME              ADDRESS  \
# 311       312  University of Pennsylvania        407 S 40TH ST
# 312       313  University of Pennsylvania     127-29 SPRUCE ST
# 313       314  University of Pennsylvania     4000 CHESTNUT ST
# 314       315  University of Pennsylvania        212 S 42ND ST
# 315       316  University of Pennsylvania       3926 SPRUCE ST
# ..        ...                         ...                  ...
# 510       511  University of Pennsylvania  3704-06 LOCUST WALK
# 511       512  University of Pennsylvania       3905 SPRUCE ST
# 512       513  University of Pennsylvania  3801-51 LOCUST WALK
# 513       514  University of Pennsylvania     3914 LOCUST WALK
# 514       515  University of Pennsylvania     4039 CHESTNUT ST
#
#                     BUILDING_D PARCEL_ID     BRT_ID  TENCODE_ID  GROSS_AREA  \
# 311    APTS  5-50 UNTS MASONRY     69436  881601900  8859000407        1757
# ...

# %%
USERNAME = 'postgres'
PASSWORD = 'postgres'
DATABASE = 'assignment_2'

# %%
engine = sqa.create_engine(
    f'postgresql://{USERNAME}:{PASSWORD}@localhost:5432/{DATABASE}'
)
df.to_postgis(
    'penn',
    engine,
    dtype={'geog': Geography()},
    schema='phl',
    if_exists='replace',
    index=False,
)

# %%
df.dtypes
# Out:
# STATEFP       object
# COUNTYFP      object
# TRACTCE       object
# BLKGRPCE      object
# GEOID         object
# NAMELSAD      object
# MTFCC         object
# FUNCSTAT      object
# ALAND          int64
# AWATER         int64
# INTPTLAT      object
# INTPTLON      object
# geog        geometry
# dtype: object
